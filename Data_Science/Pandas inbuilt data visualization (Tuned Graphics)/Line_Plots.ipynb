# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df1 = sns.load_dataset('tips')
df2 = pd.read_csv('204.ece.csv')

# %%
df = pd.read_html('https://github.com/mwaskom/seaborn-data/blob/master/penguins.csv')

# %%
df = df[0]

# %%
df
# Out:
#      Unnamed: 0 species     island  culmen_length_mm  culmen_depth_mm  \
# 0           NaN  Adelie  Torgersen              39.1             18.7
# 1           NaN  Adelie  Torgersen              39.5             17.4
# 2           NaN  Adelie  Torgersen              40.3             18.0
# 3           NaN  Adelie  Torgersen               NaN              NaN
# 4           NaN  Adelie  Torgersen              36.7             19.3
# ..          ...     ...        ...               ...              ...
# 339         NaN  Gentoo     Biscoe               NaN              NaN
# 340         NaN  Gentoo     Biscoe              46.8             14.3
# 341         NaN  Gentoo     Biscoe              50.4             15.7
# 342         NaN  Gentoo     Biscoe              45.2             14.8
# 343         NaN  Gentoo     Biscoe              49.9             16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    MALE
# 1                186.0       3800.0  FEMALE
# 2                195.0       3250.0  FEMALE
# 3                  NaN          NaN     NaN
# 4                193.0       3450.0  FEMALE
# ..                 ...          ...     ...
# 339                NaN          NaN     NaN
# 340              215.0       4850.0  FEMALE
# 341              222.0       5750.0    MALE
# 342              212.0       5200.0  FEMALE
# 343              213.0       5400.0    MALE
#
# [344 rows x 8 columns]

# %%
df.plot.hist()

# %%
x1 = np.random.rand(100, 5)
x2 = np.random.rand(10, 5)

# %%
df3 = pd.DataFrame(x1, columns=['a','b','c','d','e'])
df4 = pd.DataFrame(x2, columns=['w','y','x','z','k'])

# %%
df4
# Out:
#           w         y         x         z         k
# 0  0.125899  0.984718  0.324933  0.030924  0.527673
# 1  0.734445  0.304842  0.964046  0.204875  0.745421
# 2  0.214644  0.414256  0.456797  0.487648  0.763481
# 3  0.409362  0.078812  0.835722  0.437880  0.488487
# 4  0.728693  0.828118  0.527843  0.242020  0.571644
# 5  0.919025  0.704659  0.359640  0.344801  0.120521
# 6  0.194212  0.833222  0.608422  0.515497  0.819964
# 7  0.774987  0.881916  0.650264  0.930533  0.243691
# 8  0.678348  0.628426  0.196167  0.328220  0.273309
# 9  0.408643  0.900142  0.388870  0.348893  0.368574

# %%
df4.plot.line()

# %%
df4.plot.kde()

# %%
df4.plot.hist()
