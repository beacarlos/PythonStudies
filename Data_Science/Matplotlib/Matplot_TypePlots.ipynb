# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,20)
y = x*x
z = y+x

# %%
plt.plot(x,y)
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.fill(x,y)
