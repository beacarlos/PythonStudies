# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,10,20)
y = x*x
z = y+x

# %%
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Titulo do grafico")
# Out:
# Text(0.5, 1.0, 'Titulo do grafico')
