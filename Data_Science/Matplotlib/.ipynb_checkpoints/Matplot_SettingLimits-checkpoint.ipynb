# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,20)
y = x*x
z = y+x

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.plot(x,y)
axes.set_xlim([0,10])
axes.set_ylim([0,60])
# Out:
# (0, 60)
