# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,20)
y = x*x
z = y+x

# %%
plt.plot(x,y, color='b', lw=2, alpha=1, linestyle='-', marker='o', markersize=10, markerfacecolor='red', markeredgecolor='g')

# %%
plt.plot(x,y, color='red')
