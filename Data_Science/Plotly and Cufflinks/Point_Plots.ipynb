# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import plotly as pl
import plotly.offline as po
import cufflinks as cf

# %%
#Poder utilizar em modo offline
po.init_notebook_mode(connected=True) 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.rand(100,5), columns=['A','B','C','D','E'])

# %%
df
# Out:
#            A         B         C         D         E
# 0   0.014669  0.134418  0.884929  0.876437  0.344721
# 1   0.618433  0.481095  0.925803  0.399868  0.364363
# 2   0.340941  0.954978  0.112130  0.411526  0.316143
# 3   0.908380  0.188146  0.767571  0.138113  0.352303
# 4   0.384909  0.557666  0.964845  0.039592  0.122744
# ..       ...       ...       ...       ...       ...
# 95  0.493113  0.303317  0.097871  0.494916  0.688906
# 96  0.388337  0.930240  0.048847  0.620627  0.480365
# 97  0.497792  0.933302  0.017174  0.310725  0.371855
# 98  0.190331  0.086161  0.270642  0.137547  0.438324
# 99  0.407708  0.093751  0.362904  0.099342  0.629309
#
# [100 rows x 5 columns]

# %%
df = pd.DataFrame({'X':['A','B','C','D','E'], 'Y':[1,2,3,4,5], 'Z':[7,8,9,10,11]})

# %%
df.iplot(kind="scatter", x='A', y='B', mode='markers')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7cbe177c24d2> in <module>
# ----> 1 df.iplot(kind="scatter", x='A', y='B', mode='markers')
#
# C:\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     824                                         df=pd.DataFrame({df.name:df})
#     825                                 if x:
# --> 826                                         df=df.set_index(x)
#     827                                 if y and secondary_y:
#     828                                         _y = [y] if not isinstance(y, list) else y
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['A'] are in the columns"

# %%
df.iplot(kind="scatter", x='A', y='B', mode='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-7166601e5564> in <module>
# ----> 1 df['A'].iplot(kind="scatter", x='A', y='B', mode='')
#
# C:\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     830                                         df=df[_y + _secondary_y]
#     831                                 elif y:
# --> 832                                         df=df[y]
#     833                                 if kind=='area':
#     834                                         df=df.transpose().fillna(0).cumsum().transpose()
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'B'

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="e5a13d2a-bb57-4e71-826f-fcd4126c004d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e5a13d2a-bb57-4e71-826f-fcd4126c004d")) {
#                     Plotly.newPlot(
#                         'e5a13d2a-bb57-4e71-826f-fcd4126c004d',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "A", "nbinsx": 10, "opacity": 0.8, "orientation": "v", "type": "histogram", "x": [0.8972066577762172, 0.767818793763248, 0.2380021847759144, 0.6124652005257445, 0.9665219002255938, 0.9376777678710613, 0.6387353089179865, 0.14234977980822672, 0.5464073647883614, 0.671272896871713, 0.005158809828967104, 0.6202616447458839, 0.93803857657378, 0.35433339559485, 0.1821829239767031, 0.6916020154743786, 0.5178671971908678, 0.49121439777895637, 0.9967048923705297, 0.2955056586782274, 0.7484835630461875, 0.38657122280775913, 0.2901240855099041, 0.2951674033641344, 0.6358724122615851, 0.7991494356369436, 0.3083917307737901, 0.29508424993593363, 0.6384125853575099, 0.06770872422144025, 0.3203396121445523, 0.5418396476032245, 0.0385903559775812, 0.6747115567339023, 0.6393882074651557, 0.2585932752260198, 0.5251902742