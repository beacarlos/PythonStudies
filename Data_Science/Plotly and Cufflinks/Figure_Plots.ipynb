# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import plotly as pl
import plotly.offline as po
import cufflinks as cf

# %%
#Poder utilizar em modo offline
po.init_notebook_mode(connected=True) 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.DataFrame(np.random.rand(100,5), columns=['A','B','C','D','E'])

# %%
df
# Out:
#            A         B         C         D         E
# 0   0.927298  0.579292  0.327864  0.933073  0.235657
# 1   0.340991  0.377561  0.191972  0.290145  0.215015
# 2   0.466627  0.548544  0.154969  0.505906  0.054894
# 3   0.391890  0.910913  0.937569  0.892690  0.974576
# 4   0.227170  0.037549  0.093185  0.858316  0.560690
# ..       ...       ...       ...       ...       ...
# 95  0.261940  0.967027  0.948888  0.877450  0.539808
# 96  0.219939  0.854155  0.740302  0.409463  0.313003
# 97  0.816911  0.198516  0.838915  0.162442  0.827519
# 98  0.836575  0.075394  0.912502  0.872588  0.194283
# 99  0.216786  0.679036  0.260167  0.465707  0.269051
#
# [100 rows x 5 columns]

# %%
df2 = pd.DataFrame({'X':['a','b','c','d','e'], 'Y':[1,2,3,4,5], 'Z':[7,8,9,10,11]})

# %%
df2
# Out:
#    X  Y   Z
# 0  a  1   7
# 1  b  2   8
# 2  c  3   9
# 3  d  4  10
# 4  e  5  11

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="33ed8a65-c678-416a-8b17-8e488247c260" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("33ed8a65-c678-416a-8b17-8e488247c260")) {
#                     Plotly.newPlot(
#                         '33ed8a65-c678-416a-8b17-8e488247c260',
# ...

# %%
df['B'].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="52243fbf-e75c-40b0-9b71-08309fef4df6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("52243fbf-e75c-40b0-9b71-08309fef4df6")) {
#                     Plotly.newPlot(
#                         '52243fbf-e75c-40b0-9b71-08309fef4df6',
# ...

# %%
df2.iplot(kind='bar', x='X', y='Y')
# Out:
# <div>
#
#
#             <div id="8b4ea26d-6184-4558-a09d-ac9596dc8534" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8b4ea26d-6184-4558-a09d-ac9596dc8534")) {
#                     Plotly.newPlot(
#                         '8b4ea26d-6184-4558-a09d-ac9596dc8534',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Y", "orientation": "v", "text": "", "type": "bar", "x": ["a", "b", "c", "d", "e"], "y": [1, 2, 3, 4, 5]}],
# ...

# %%
df.sum().iplot(kind='bar', color='blue')
# Out:
# <div>
#
#
#             <div id="29ea68d3-5644-447e-9f39-2be917d0a0cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("29ea68d3-5644-447e-9f39-2be917d0a0cc")) {
#                     Plotly.newPlot(
#                         '29ea68d3-5644-447e-9f39-2be917d0a0cc',
#                         [{"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D", "E"], "y": [49.31290070478457, 49.04264013481971, 49.795400629183575, 51.619714597522794, 50.09204614880381]}],
# ...

# %%
df.iplot(kind='histogram')
# Out:
# <div>
#
#
#             <div id="97b5657f-e4ec-4082-ba64-82a8d767aceb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("97b5657f-e4ec-4082-ba64-82a8d767aceb")) {
#                     Plotly.newPlot(
#                         '97b5657f-e4ec-4082-ba64-82a8d767aceb',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="3eff8cbb-4c6e-4389-9658-fb20e65be939" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3eff8cbb-4c6e-4389-9658-fb20e65be939")) {
#                     Plotly.newPlot(
#                         '3eff8cbb-4c6e-4389-9658-fb20e65be939',
# ...

# %%
df.iplot(kind='scatter3d', x='A', y='B', z='C', size=15,
                             title='Cufflinks - Scatter 3D Chart',colors=['blue','pink'],width=0.5,margin=(0,0,0,0),
                             opacity=1)
# Out:
# <div>
#
#
#             <div id="eda3811d-5b50-48dc-b1e4-76a3e63c926e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eda3811d-5b50-48dc-b1e4-76a3e63c926e")) {
#                     Plotly.newPlot(
#                         'eda3811d-5b50-48dc-b1e4-76a3e63c926e',
# ...
