# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import plotly as pl
import plotly.offline as po
import cufflinks as cf

# %%
#Poder utilizar em modo offline
po.init_notebook_mode(connected=True) 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.DataFrame(np.random.rand(100,5), columns=['A','B','C','D','E'])

# %%
df
# Out:
#            A         B         C         D         E
# 0   0.131265  0.348191  0.672434  0.397502  0.627756
# 1   0.725161  0.285672  0.426761  0.943253  0.635275
# 2   0.615311  0.309124  0.433003  0.291774  0.879443
# 3   0.883306  0.137571  0.298461  0.388345  0.685758
# 4   0.800549  0.793081  0.023413  0.465252  0.852188
# ..       ...       ...       ...       ...       ...
# 95  0.221433  0.405671  0.686654  0.861189  0.877481
# 96  0.653016  0.163930  0.535943  0.661214  0.810849
# 97  0.346348  0.501886  0.835188  0.214894  0.192282
# 98  0.995799  0.887712  0.065119  0.341806  0.462749
# 99  0.108782  0.761608  0.168587  0.042429  0.293309
#
# [100 rows x 5 columns]

# %%
df2 = pd.DataFrame({'X':[22,7,5,6,8], 'Y':[1,2,3,4,5], 'Z':[7,8,9,10,11]})

# %%
df.iplot(kind="scatter", x='A', y='B', mode='markers', size=7, symbol='x', color='blue')
# Out:
# <div>
#
#
#             <div id="0dd19892-81a8-433f-8168-c80184f4651a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0dd19892-81a8-433f-8168-c80184f4651a")) {
#                     Plotly.newPlot(
#                         '0dd19892-81a8-433f-8168-c80184f4651a',
# ...

# %%
df.iplot(kind="scatter", x='A', y='B', mode='')
# Out:
# <div>
#
#
#             <div id="b507c819-03ed-4ae0-b482-ef321ad4ac4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b507c819-03ed-4ae0-b482-ef321ad4ac4b")) {
#                     Plotly.newPlot(
#                         'b507c819-03ed-4ae0-b482-ef321ad4ac4b',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="26100a57-27bd-4568-ae51-eaf076c22797" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("26100a57-27bd-4568-ae51-eaf076c22797")) {
#                     Plotly.newPlot(
#                         '26100a57-27bd-4568-ae51-eaf076c22797',
# ...

# %%
df2.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="2f508192-cbbe-4165-a4d0-7c9c0efdeeb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2f508192-cbbe-4165-a4d0-7c9c0efdeeb6")) {
#                     Plotly.newPlot(
#                         '2f508192-cbbe-4165-a4d0-7c9c0efdeeb6',
# ...

# %%
cf.datagen.sinwave(10,.2).iplot(kind='surface', theme='so', colorscale='brbg', margin=(0,0,0,0))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-228a6e10e1c2> in <module>
# ----> 1 cf.datagen.sinwave(10,.2).iplot(kind='surface', theme='sun', colorscale='brbg', margin=(0,0,0,0))
#
# C:\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     708         if theme is None:
# ...
