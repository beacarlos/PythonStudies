# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
dots = sns.load_dataset('dots')

# %%
dots.head(10)
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487
# 5  dots     T1   -80       51.2    34.987571
# 6  dots     T1   -60        0.0    32.868526
# 7  dots     T1   -60        3.2    35.119048
# 8  dots     T1   -60        6.4    34.841076
# 9  dots     T1   -60       12.8    35.648148

# %%
dots[dots["align"] == 'dots']
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 389  dots     T2   680        3.2    37.806267
# 390  dots     T2   700        0.0    43.464959
# 391  dots     T2   700        3.2    38.994559
# 392  dots     T2   720        0.0    41.987121
# 393  dots     T2   720        3.2    41.716057
#
# [394 rows x 5 columns]

# %%
sns.pairplot(dots, hue='choice') #hue escolher uma coluna nao numerica para separação

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = sns.pairplot(tips, hue='day', kind='scatter')
x.map_diag(sns.distplot) #Colocou um grafico de distribuição sobre os graficos da diagonal
x.map_lower(sns.kdeplot)
