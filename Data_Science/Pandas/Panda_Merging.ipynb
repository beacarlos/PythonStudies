# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({'key':[1,2,3], 'a':[4,3,2], 'b':[2,2,2]})
df2 = pd.DataFrame({'key':[1,2,3], 'c':[1,2,9], 'd':[5,8,9]})

# %%
pd.merge(df1,df2, how = 'outer', on='key')
# Out:
#    key  a  b  c  d
# 0    1  4  2  1  5
# 1    2  3  2  2  8
# 2    3  2  2  9  9

# %%
df1.sort_values('a')
# Out:
#    key  a  b
# 2    3  2  2
# 1    2  3  2
# 0    1  4  2

# %%
df1['b'].nunique()
# Out:
# 1
